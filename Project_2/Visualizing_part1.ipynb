# %% [markdown]
# # Visualizing

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Data/training_cleaned.csv', low_memory = True)

# %%
df.columns.tolist()
# Out:
# ['gender',
#  'age',
#  'hypertension',
#  'heart_disease',
#  'ever_married',
#  'work_type',
#  'Residence_type',
#  'avg_glucose_level',
#  'bmi',
#  'smoking_status',
#  'stroke']

# %%
## Bar graph for Financial Situation by Gender

sns.set(style="whitegrid")
plt.figure(figsize=(15, 10))
sns.countplot(x="stroke", hue="gender", data=df, palette="Set2")
plt.title("Stroke Likelihood by Gender",fontsize=20)
plt.xlabel("Stroke",fontsize=16)
plt.ylabel("Count",fontsize=16)
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.legend(title="gender")
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(15, 10))

## Graphing the KDE plot by Class

sns.kdeplot(data=df, x='age', hue = 'gender') # By class -- all
plt.title("KDE Plot by Age",fontsize=20)


# Display the plot (for interactive environments)

plt.show()
# Out:
# /apps/software/standard/compiler/gcc/9.2.0/jupyter_conda/2020.11-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
# Set the figure size
plt.figure(figsize=(15, 10))

## Graphing the KDE plot by Class

sns.kdeplot(data=df, x='avg_glucose_level', hue = 'gender') # By class -- all
plt.title("KDE Plot by Age",fontsize=20)


# Display the plot (for interactive environments)

plt.show()
# Out:
# /apps/software/standard/compiler/gcc/9.2.0/jupyter_conda/2020.11-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
# Set the figure size
plt.figure(figsize=(15, 10))

## Graphing the KDE plot by Class

sns.kdeplot(data=df, x='bmi', hue = 'gender') # By class -- all
plt.title("KDE Plot by Age",fontsize=20)


# Display the plot (for interactive environments)

plt.show()
# Out:
# /apps/software/standard/compiler/gcc/9.2.0/jupyter_conda/2020.11-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
X = df.iloc[:,[1,7,8]]
# X = df[:,[1,7,8]]
# X.plot.box() # Hmm, outliers

df.head()

df.boxplot(column=['age'], by= 'stroke')
# Out:
# <AxesSubplot:title={'center':'age'}, xlabel='stroke'>

# %%
df.boxplot(column=['bmi'], by= 'stroke')
# Out:
# <AxesSubplot:title={'center':'bmi'}, xlabel='stroke'>

# %%
df.boxplot(column=['avg_glucose_level'], by= 'stroke')
# Out:
# <AxesSubplot:title={'center':'avg_glucose_level'}, xlabel='stroke'>

# %%
# Sample data
labels = ['Male','Female']
sizes = [1611, 2317]

# Create a pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)

# Set plot title
plt.title('Males and Females in the Dataset')

# Show the plot
plt.show()

# %%
## Summary Statistics
summary_stats = df['work_type'].describe()
print(summary_stats)
print('\n')

# 2317 female
# 1611 male

# 3928 total work types
# private sector employment: 2238
# Out:
# count        3928
# unique          5
# top       Private
# freq         2238
# Name: work_type, dtype: object

# %%
# Sample data
labels = ['Male','Female']
sizes = [1611, 2317]

# Create a pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)

# Set plot title
plt.title('Pie Chart Example')

# Show the plot
plt.show()
