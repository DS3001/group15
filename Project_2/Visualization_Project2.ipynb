# %%
import numpy as np
import pandas as pd
! git clone https://github.com/DS3001/group15
# Out:
# Cloning into 'group15'...
# remote: Enumerating objects: 100, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 100 (delta 21), reused 5 (delta 3), pack-reused 58
# Receiving objects: 100% (100/100), 3.04 MiB | 0 bytes/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
df = pd.read_csv('./group15/Project_2/training_cleaned.csv')

# %%
print(df.head(10))
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  36.0             0              0          Yes       Govt_job
# 1  Female  45.0             0              0          Yes       Govt_job
# 2    Male  58.0             0              0           No  Self-employed
# 3  Female  61.0             0              0          Yes  Self-employed
# 4  Female  78.0             0              0           No        Private
# 5    Male  34.0             0              0           No        Private
# 6  Female  78.0             1              1          Yes        Private
# 7  Female  37.0             0              0          Yes        Private
# 8    Male  63.0             0              0          Yes        Private
# 9  Female  37.0             0              0          Yes       Govt_job
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban              65.87  32.2  formerly smoked       0
# ...

# %%
# making a kernel density plot of stroke grouped by age 
import seaborn as sns
import matplotlib.pyplot as plt
y = 'stroke'
gender = 'gender'
sns.kdeplot(data=df, x=y, hue = gender, palette = 'rocket') 
plt.title("KDE Plot of Stroke by Gender")
# Out:
# /apps/software/standard/compiler/gcc/9.2.0/jupyter_conda/2020.11-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'KDE Plot of Stroke by Gender')

# %%
# going to make a kernel density plot of stroke grouped by smoking status

# %%
smoking = 'smoking_status'
sns.kdeplot(data=df,x=y,hue=smoking, palette = 'rocket')
plt.title('KDE Plot of Stroke by Smoking Status')
# Out:
# Text(0.5, 1.0, 'KDE Plot of Stroke by Smoking Status')

# %%
# variables i am working with are : gender(categorical) age(numerical) hypertension(binary) heart_disease(binary) and smoking_status(categorical)
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.countplot(x="stroke", hue="hypertension", data=df, palette="rocket")
plt.title("Bar Graph of Stroke by Hypertension")
plt.xlabel("Experience of a Stroke")
plt.ylabel("Count")
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.countplot(x="stroke", hue="heart_disease", data=df, palette="rocket")
plt.title("Bar Graph of Stroke by Marriage Status")
plt.xlabel("Experience of a Stroke")
plt.ylabel("Count")
plt.show()

# %%
# simply wanted to look at the difference of individuals in the data who have had a stroke vs who hasnt 
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.countplot(x="stroke",data=df, palette="rocket")
plt.title("Bar Graph Count of Stroke")
plt.xlabel("Experience of a Stroke")
plt.ylabel("Count")
plt.show()

# %%
# variables i am working with are : gender(categorical) age(numerical) hypertension(binary) heart_disease(binary) and smoking_status(categorical)
smoking = 'smoking_status'
heart = 'heart_disease'
sns.kdeplot(data=df,x=y,hue=heart, palette = 'rocket')
plt.title('KDE Plot of Stroke by Heart Disease')
# Out:
# Text(0.5, 1.0, 'KDE Plot of Stroke by Heart Disease')

# %%
# variables i am working with are : gender(categorical) age(numerical) hypertension(binary) heart_disease(binary) and smoking_status(categorical)
smoking = 'smoking_status'
heart = 'heart_disease'
hypertension = 'hypertension'
sns.kdeplot(data=df,x=y,hue=hypertension, palette = 'rocket')
plt.title('KDE Plot of Stroke by Hypertension')
# Out:
# Text(0.5, 1.0, 'KDE Plot of Stroke by Hypertension')
