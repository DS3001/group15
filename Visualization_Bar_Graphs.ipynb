# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/cleaned_data.csv', low_memory = True)

# %%
import seaborn as sns
var = 'class'
sns.histplot(df[var])
print(df[var].describe)
# Out:
# <bound method NDFrame.describe of 0         middle class
# 1         middle class
# 2        working class
# 3         middle class
# 4         middle class
#              ...
# 29422      lower class
# 29423    working class
# 29424     middle class
# 29425     middle class
# 29426     middle class
# Name: class, Length: 29427, dtype: object>

# %%
svar = 'finalter'
sns.histplot(df[svar])
print(df[svar].describe)
# Out:
# <bound method NDFrame.describe of 0        stayed same
# 1        stayed same
# 2             better
# 3             better
# 4             better
#             ...
# 29422    stayed same
# 29423         better
# 29424         better
# 29425    stayed same
# 29426    stayed same
# Name: finalter, Length: 29427, dtype: object>

# %%
vars = 'satfin'
sns.histplot(df[var])
print(df[var].describe)
# Out:
# <bound method NDFrame.describe of 0         middle class
# 1         middle class
# 2        working class
# 3         middle class
# 4         middle class
#              ...
# 29422      lower class
# 29423    working class
# 29424     middle class
# 29425     middle class
# 29426     middle class
# Name: class, Length: 29427, dtype: object>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.columns.tolist()
# Out:
# ['year', 'sex', 'class', 'satfin', 'finalter']

# %%
var1 = 'sex' #need numeric -- gender
var2 = 'year'
cat1 = 'class'
cat2 = 'finalter' # finalter

# %%
male_df = df[df['sex'] == 'male']
female_df = df[df['sex'] == 'female']

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

# %%
sns.histplot(data=df, x= 'satfin', hue = 'sex')
# Out:
# <Axes: xlabel='satfin', ylabel='Count'>

# %% [markdown]
# No women in this survey are in the upper class

# %%
sns.histplot(data=df, x= 'satfin', hue = 'sex')
# Out:
# <Axes: xlabel='satfin', ylabel='Count'>

# %%
sns.histplot(data=df, x= 'finalter', hue = 'sex')
# Out:
# <Axes: xlabel='finalter', ylabel='Count'>
